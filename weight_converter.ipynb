# %%
# weight converter 
weight=int(input("enter your weight"))
ch=input("lbs or kg:")
if (ch.lower()=='kg'  ):
    convert=weight*0.45
    print(f"you are {convert}pounds")
else:
    conert=weight/0.45
    print(f"you are {convert} pounds")
# Out:
# enter your weight 52
# lbs or kg: kg
# you are 23.400000000000002pounds

# %%
# number guessing game
target=5

i=1

while (i<=3):
    guess=int(input("guess:"))
    if (guess==target):
        print('you win!')
        break
    else:
        print("you failed!!")
    i+=1
if i>3:
    
    print("better luck next time !")
# Out:
# guess: 6
# you failed!!
# guess: 5
# you win!

# %%
l=[1,2,3,4,5]
print(enumerate (i,l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 l=[1,2,3,4,5]
# ----> 2 print(enumerate (i,l))
#
# TypeError: 'list' object cannot be interpreted as an integer
