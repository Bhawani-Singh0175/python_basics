# %%
a=int(input("enetr the numbeer1:"))
b=int(input("enetr the number2:"))
c=int(input("enetr the number3:"))
d=int(input("enetr the number4:"))
if (a>b and a>c and a>d ):
    print("a is greater ")
elif (b>a and b>c and b>d):
    print("b is greater ")
elif (c>a and c>b and c>d):
    print("c is greater" )
else :
    print("d is greater ")
# Out:
# enetr the numbeer1: 25
# enetr the number2: 6
# enetr the number3: 322
# enetr the number4: 2
# c is greater

# %%
maths=int(input("enter marks1:"))
sst=int(input("enter marks2:"))
chem=int(input("enter marks3:"))
if (maths>40 and sst>40 and chem>40):
    print("student passed ")
else:
    print("student failed")
# Out:
# enter marks1: 20
# enter marks2: 60
# enter marks3: 80
# student failed

# %%
name=input("enter your name:")
if (len(name)<10):
    print("yes it is valid ")
else:
    print("not valid ")
# Out:
# enter your name: sbdvicsicosvfcoyc
# not valid

# %%
l=["bhawani","ram","bhoomi","sudeep","abhay"]
t=input("enter your name")
if (t in l):
    print("yes it is present")
else:
    print("not present")
# Out:
# enter your name adi
# not present

# %%
marks=int(input("enter your marks:"))
if (marks>90):
    print("grade is EX...")
elif(marks>=80 and marks<=90):
    print("grade is A")
elif (marks>=70 and marks<=80):
    print("grade is B")
elif(marks>=60 and marks<=70):
    print("grade is C")
elif(marks>=50 and marks<=60):
    print("grade is D")
else:
    print("fail....")
# Out:
# enter your marks: 20
# fail....

# %%
p1="make a lot of money"
p2="buy now"
p3="subscribe now"
p4="click this "
message=input("enetr you message :")
if ((p1  in message) or (p2  in message) or (p3  in message) or (p4  in message)):
    print("this is  a spam message lol!!!...")
else:
    print("this not a  spam ")
# Out:
# enetr you message : buy now
# this is  a spam message lol!!!...

# %%
year=int(input("enter year:"))
if (year%400==0):
    print("yea this is leap year..")
elif (year%4==0 and year%100!=0):
    print("yea")

else:
    print("not a leap year..")
# Out:
# enter year: 1900
# not a leap year..

# %%
marks=45
res="pass" if marks>=45 else "fail"
print(F"result:{res}")
# Out:
# result:pass
