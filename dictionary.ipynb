# %%
#dictionary methods

# %%
a={"monday":"1","tuesday":"2","wednesday":"3","thursday":"4","friday":"5"}
print(a["monday"])
# Out:
# 1

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
print(marks.items())
# Out:
# dict_items([('bhawani', '18'), ('bhoomi', '20'), ('sudeep', '15'), ('15', 'abhay'), ('10', 'vansh')])

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
print(marks.values())
# Out:
# dict_values(['18', '20', '15', 'abhay', 'vansh'])

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
print(marks.keys())
# Out:
# dict_keys(['bhawani', 'bhoomi', 'sudeep', '15', '10'])

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
marks.update({"sudeep":10})
print(marks)
marks.update({"suresh":9})
print(marks)
# Out:
# {'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh'}
# {'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh', 'suresh': 9}

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
marks.get("suresh")

# %%
marks={'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh', 'suresh': 9}
marks.popitem()
print(marks)
# Out:
# {'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh'}

# %%
marks={'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh', 'suresh': 9}
marks.popitem()
print(marks)
# Out:
# {'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh'}

# %%
marks={'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay', '10': 'vansh'}
marks.popitem()
print(marks)
# Out:
# {'bhawani': '18', 'bhoomi': '20', 'sudeep': 10, '15': 'abhay'}

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
print(marks.values())
# Out:
# dict_values(['18', '20', '15', 'abhay', 'vansh'])

# %%
marks={"bhawani":"18","bhoomi":"20","sudeep":"15","15":"abhay","10":"vansh"}
print(marks.keys())
# Out:
# dict_keys(['bhawani', 'bhoomi', 'sudeep', '15', '10'])

# %%
#sets methods

# %%
s={1,5,9,23,7,6,52}
s.add(555)
print(s)
s.remove(6)
print(s)
# Out:
# {1, 52, 5, 6, 7, 23, 9, 555}
# {1, 52, 5, 7, 23, 9, 555}

# %%
s1={1,2,3}
s2={4,5,6}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5, 6}
