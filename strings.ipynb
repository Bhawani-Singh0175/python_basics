# %%
#string slicing

# %%
name="HARRY"
name_sort=name[0:3]
print(name_sort)
# Out:
# HAR

# %%
word="abcde"
word[1:5:2]
# Out:
# 'bd'

# %%
word="abcde"
word[0:5:2]
# Out:
# 'ace'

# %%
word="abcde"
word[1:5:0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 word="abcde"
# ----> 2 word[1:5:0]
#
# ValueError: slice step cannot be zero

# %%
#string function

# %%
name="HARRY"
print(len(name))
# Out:
# 5

# %%
name="bhawani"
name.endswith("awa")
# Out:
# False

# %%
name="bhawani"
name.endswith("ani")
# Out:
# True

# %%
name="bhawani"
print(name.count("a"))
# Out:
# 2

# %%
name="bhawani"
print(name.count("g"))
# Out:
# 0

# %%
name="bhawani"
print(name.find("a"))
# Out:
# 2

# %%
name="bhawani"
print(name.capitalize())
# Out:
# Bhawani

# %%
name="bhawani singh"
print(name.replace("singh","chundawat"))
# Out:
# bhawani chundawat

# %%
name=" bhawani "
name.strip()
# Out:
# 'bhawani'

# %%
name=" bhawani "
name.lstrip()
# Out:
# 'bhawani '

# %%
name=" bhawani "
name.strip()
# Out:
# 'bhawani'

# %%
name="a,b,c"
name.split(",")
# Out:
# ['a', 'b', 'c']

# %%
name="bhawani"
age=20
print(f"my name is {name} and i am {age}")
# Out:
# my name is bhawani and i am 20

# %%
name="bhawani is a good boy \n and very \"inteligent\" boy"
print(name)
# Out:
# bhawani is a good boy
#  and very "inteligent" boy

# %%
Name=input("enter the your name: ")
print(f"good afternoon {Name}")
# Out:
# enter the your name:  bhawani
# good afternoon bhawani

# %%
latter="dear <name>,you are selected <date>"
print(latter.replace("<name>","bhawani").replace("<date>","2025-12-05"))
#chaning the .replace
# Out:
# dear bhawani,you are selected 2025-12-05

# %%
word="bhawnai is a  very nice boy "
print(word.find("  "))
# Out:
# 12

# %%
word="bhawnai is a  very nice boy "
print(word.replace("  "," "))
# Out:
# bhawnai is a very nice boy

# %%
name="amit"
f_name="ram"
print(f"i am {name}.my father name is {f_name}")
# Out:
# i am amit.my father name is ram

# %%
a="bhawni "
a.rstrip()
print(a)
# Out:
# bhawni

# %%
names = input("Enter names: ")      # "ram,shyam,geeta"
lst = names.split(",")              # ['ram','shyam','geeta']
result = "-".join(lst)
print(lst)
print(result)
# Out:
# Enter names:  bhawni
# ['bhawni']
# bhawni

# %%
names = input("Enter names: ")
print(names.split())
# Out:
# Enter names:  bhawani ramu
# ['bhawani', 'ramu']
