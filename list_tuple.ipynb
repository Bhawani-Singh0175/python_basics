# %%
#list methods

# %%
l=["bhawani","bhoomi",12.5,12,False,"abhay","tanisha"]
l.append("taniya")
print(l)
# Out:
# ['bhawani', 'bhoomi', 12.5, 12, False, 'abhay', 'tanisha', 'taniya']

# %%
a=[15,55,35,484,1,59,6666]
a.sort()
print(a)
# Out:
# [1, 15, 35, 55, 59, 484, 6666]

# %%
a=[15,55,35,484,1,59,6666]
a.reverse()
print(a)
# Out:
# [6666, 59, 1, 484, 35, 55, 15]

# %%
a=[15,55,35,484,1,59,6666]
a.insert(4,22)
print(a)
# Out:
# [15, 55, 35, 484, 22, 1, 59, 6666]

# %%
l1=[15, 55, 35, 484, 22, 1, 59, 6666]
print(l1.pop(4))
print(l1)
# Out:
# 22
# [15, 55, 35, 484, 1, 59, 6666]

# %%
l1=[15, 55, 35, 484, 22, 1, 59, 6666]
print(l1.remove(22))
print(l1)
# Out:
# None
# [15, 55, 35, 484, 1, 59, 6666]

# %%
#tuple methods

# %%
a=(1,2,5,54,745,4,548,2,2)
a.count(6000)
# Out:
# 0

# %%
a=(1,2,5,54,745,4,548,2,2)
a.index(5)
# Out:
# 2

# %%
t1=(1,2,56,855)
t2=(3,4)
print(t1+t2)
print(t1*2)
print(3 not in t1)
print(2 not in t1)
print(len(t1))
print(max(t1))
print(min(t1))
# Out:
# (1, 2, 56, 855, 3, 4)
# (1, 2, 56, 855, 1, 2, 56, 855)
# True
# False
# 4
# 855
# 1

# %%
t=(1,2,3,4,5)
a,*b,c=t
print(a,b,c)
# Out:
# 1 [2, 3, 4] 5

# %%
t=(1,2,3)
a,b,c=t
print(a,b,c)
# Out:
# 1 2 3

# %%
a=1
b=2
c=3
t=a,b,c
print(t)
# Out:
# (1, 2, 3)

# %%
a=1
b=2
a,b=b,a
print(a,b)
# Out:
# 2 1

# %%
fruits = []

for i in range(7):
    fruit = input(f"Enter fruit {i+1}: ")
    fruits.append(fruit)

print("Fruits list:", fruits)
# Out:
# Enter fruit 1:  mango
# Enter fruit 2:  orange
# Enter fruit 3:  graps
# Enter fruit 4:  banna
# Enter fruit 5:  apple
# Enter fruit 6:  angoor
# Enter fruit 7:  kela
# Fruits list: ['mango', 'orange', 'graps', 'banna', 'apple', 'angoor', 'kela']
